# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# loading dataset
df = pd.read_csv("../data/cleaned/cleaned_telecom_customer_churn.csv")
df.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 2  0011-IGKFF    Male   78     Yes                     0      Martinez
# 3  0013-EXCHZ  Female   75     Yes                     0     Camarillo
# 4  0013-MHZWF  Female   23      No                     3      Midpines
#
#    Number of Referrals  Tenure in Months    Offer Phone Service  ...  \
# 0                    2                 9  Unknown           Yes  ...
# 1                    0                 4  Offer E           Yes  ...
# 2                    1                13  Offer D           Yes  ...
# 3                    3                 3  Unknown           Yes  ...
# 4                    0                 9  Offer E           Yes  ...
#
#     Payment Method Monthly Charge Total Charges Total Revenue Customer Status  \
# ...

# %%
# converting "customer status" (target) to binary
df["Churn_status"] = df["Customer Status"].map({
    "Churned": 1,
    "Stayed": 0,
    "Joined": 0
})

# %%
# replacing binary column with 1, 0
df["Married"] = df["Married"].replace(["Yes", "No"], [1,0])
df["Phone Service"] = df["Phone Service"].replace(["Yes", "No"], [1,0])
# df["Multiple Lines"] = df["Multiple Lines"].replace(["Yes", "No"], [1,0])
df["Multiple Lines"] = df["Multiple Lines"].map({
    "Yes": 1,
    "No": 0,
    "Unknown": 0
})
df["Internet Service"] = df["Internet Service"].replace(["Yes", "No"], [1,0])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4040\604783954.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Married"] = df["Married"].replace(["Yes", "No"], [1,0])
# C:\Users\USER\AppData\Local\Temp\ipykernel_4040\604783954.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Phone Service"] = df["Phone Service"].replace(["Yes", "No"], [1,0])
# ...

# %%
# Average Revenue Per Month
df["Avg_Revenue_Per_Month"] = df["Total Revenue"] / (df["Tenure in Months"])

# %%
# Tenure Buckets
df["Tenure"] = pd.cut(
    df["Tenure in Months"],
    bins=[0, 6, 12, 24, 48, 72],
    labels=["0-6m", "6-12m", "1-2y", "2-4y", "4-6y"]
)

# %%
# Count Number of Services
service_cols = [
    "Online Security",
    "Online Backup",
    "Device Protection Plan",
    "Premium Tech Support",
    "Streaming TV",
    "Streaming Movies",
    "Streaming Music",
    "Unlimited Data"
]

df["Total Internet Services"] = df[service_cols].apply(lambda x: (x=="Yes").sum(), axis=1)

# %%
df.head()
# Out:
#   Customer ID  Gender  Age  Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37        1                     0  Frazier Park
# 1  0004-TLHLJ    Male   50        0                     0    Costa Mesa
# 2  0011-IGKFF    Male   78        1                     0      Martinez
# 3  0013-EXCHZ  Female   75        1                     0     Camarillo
# 4  0013-MHZWF  Female   23        0                     3      Midpines
#
#    Number of Referrals  Tenure in Months    Offer  Phone Service  ...  \
# 0                    2                 9  Unknown              1  ...
# 1                    0                 4  Offer E              1  ...
# 2                    1                13  Offer D              1  ...
# 3                    3                 3  Unknown              1  ...
# 4                    0                 9  Offer E              1  ...
#
#    Customer Status   Churn Category                   Churn Reason  \
# ...

# %%
# df_model.to_csv("../data/cleaned/model_telecom_customer_churn.csv", index=False)
